# %%
import pandas as pd
data = [10, 20, 30, 40, 50]
serie = pd.Series(data)
print(serie)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
materias = pd.Series([
    "Programación",
    "Bases de Datos",
    "Estadística",
    "Inglés",
    "Matemáticas"
])

print(materias)
# Out:
# 0      Programación
# 1    Bases de Datos
# 2       Estadística
# 3            Inglés
# 4       Matemáticas
# dtype: str

# %%
precios = pd.Series([2500, 3700, 5900, 1200, 4800])

print(precios)
print("Tipo de dato:", precios.dtype)
# Out:
# 0    2500
# 1    3700
# 2    5900
# 3    1200
# 4    4800
# dtype: int64
# Tipo de dato: int64

# %%
valores_bool = pd.Series([True, False, True, True, False])

print(valores_bool)
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
serie = pd.Series([5, 10, 15, 20, 25, 30])

print(serie.head(3))
# Out:
# 0     5
# 1    10
# 2    15
# dtype: int64
