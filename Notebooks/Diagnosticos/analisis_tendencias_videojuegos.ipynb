# %% [markdown]
# # Analisis de tendencias de videojuegos
#
# Este cuaderno desarrolla un diagnostico inicial de calidad de datos siguiendo el flujo solicitado en la actividad.

# %% [markdown]
# ## 1. Preparacion del entorno
#
# Se importan las librerias solicitadas para realizar la inspeccion y documentar hallazgos basicos de calidad.

# %%
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

try:
    import seaborn as sns
except ImportError:
    sns = None

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')

# %% [markdown]
# ## 2. Carga de datos
#
# Dataset analizado: **Raw Data.csv con informacion de videojuegos y ventas por region.**.
#
# El archivo se encuentra en la misma carpeta del notebook para facilitar una ejecucion directa.

# %%
ruta_dataset = r'Raw Data.csv'
df = pd.read_csv(ruta_dataset)
df
# Out:
#     Rank                                          Name Platform     Year  \
# 0      1                                    Wii Sports      Wii 2,006.00
# 1      2                             Super Mario Bros.      NES 1,985.00
# 2      3                                Mario Kart Wii      Wii 2,008.00
# 3      4                             Wii Sports Resort      Wii 2,009.00
# 4      5                      Pokemon Red/Pokemon Blue       GB 1,996.00
# 5      6                                        Tetris       GB 1,989.00
# 6      7                         New Super Mario Bros.       DS 2,006.00
# 7      8                                      Wii Play     Wii  2,006.00
# 8      9                     New Super Mario Bros. Wii      Wii 2,009.00
# 9     10                                     Duck Hunt      NES 1,984.00
# 10    11                                    Nintendogs       DS 2,005.00
# 11    12                                 Mario Kart DS       DS 2,005.00
# ...

# %% [markdown]
# ## 3. Inspeccion rapida
#
# Se visualizan registros iniciales, finales y dimensiones generales del dataset.

# %%
df.head()
# Out:
#    Rank                      Name Platform     Year         Genre Publisher  \
# 0     1                Wii Sports      Wii 2,006.00        Sports  Nintendo
# 1     2         Super Mario Bros.      NES 1,985.00      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii 2,008.00        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii 2,009.00        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB 1,996.00  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.tail()
# Out:
#     Rank                                          Name Platform     Year  \
# 15    16                            Kinect Adventures!     X360 2,010.00
# 16    17                            Grand Theft Auto V      PS3 2,013.00
# 17    18                            Grand Theft Auto V     X360 2,013.00
# 18    19  Brain Age: Train Your Brain in Minutes a Day       DS      NaN
# 19    20                              Super Mario Land       GB 1,989.00
#
#        Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 15      Misc  Microsoft Game Studios     14.97      4.94      0.24
# 16    Action    Take-Two Interactive      7.01      9.27      0.97
# 17    Action    Take-Two Interactive      9.63      5.31      0.06
# 18    Puzzle                     NaN      4.75      9.26      4.16
# 19  Platform                Nintendo     10.83      2.71      4.18
#
#     Other_Sales  Global_Sales
# 15         1.67         21.82
# 16         4.14         21.40
# ...

# %%
df.shape
# Out:
# (20, 11)

# %% [markdown]
# ## 4. Diagnostico principal
#
# La salida de `info()` resume no nulos, tipos de datos y memoria consumida.

# %%
buffer = io.StringIO()
df.info(buf=buffer)
print(buffer.getvalue())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          20 non-null     int64
#  1   Name          20 non-null     str
#  2   Platform      20 non-null     str
#  3   Year          18 non-null     float64
#  4   Genre         20 non-null     str
#  5   Publisher     19 non-null     str
#  6   NA_Sales      20 non-null     float64
#  7   EU_Sales      20 non-null     float64
#  8   JP_Sales      20 non-null     float64
#  9   Other_Sales   20 non-null     float64
#  10  Global_Sales  20 non-null     float64
# dtypes: float64(6), int64(1), str(4)
# memory usage: 1.8 KB

# %% [markdown]
# ## 5. Resumen estadistico
#
# Se revisan por separado las variables numericas y las variables categoricas.

# %%
df.describe()
# Out:
#        Rank     Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# count 20.00    18.00     20.00     20.00     20.00        20.00         20.00
# mean  10.50 2,002.72     14.83      8.33      3.77         2.23         29.17
# std    5.92     9.57      8.95      5.82      2.55         1.80         13.99
# min    1.00 1,984.00      4.75      0.63      0.06         0.42         16.38
# 25%    5.75 1,998.25      9.09      5.22      2.38         0.94         21.95
# 50%   10.50 2,006.00     11.32      8.31      3.78         1.98         26.54
# 75%   15.25 2,009.00     15.78      9.26      4.34         2.86         30.54
# max   20.00 2,013.00     41.49     29.02     10.22         8.46         82.74

# %%
df.describe(include=['object', 'string'])

# %% [markdown]
# ## 6. Interpretacion inicial
#
# - La estructura combina variables numericas continuas y columnas categoricas utiles para clasificacion.
# - Se observan nulos en columnas criticas para analisis temporales y por publicador.
# - La normalizacion de texto sera un paso recomendado porque existen categorias afectadas por espacios en blanco.
