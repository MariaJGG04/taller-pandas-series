# %% [markdown]
# # Analisis del proyecto personal
#
# Este cuaderno desarrolla un diagnostico inicial de calidad de datos siguiendo el flujo solicitado en la actividad.

# %% [markdown]
# ## 1. Preparacion del entorno
#
# Se importan las librerias solicitadas para realizar la inspeccion y documentar hallazgos basicos de calidad.

# %%
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

try:
    import seaborn as sns
except ImportError:
    sns = None

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')

# %% [markdown]
# ## 2. Carga de datos
#
# Dataset analizado: **tech_jobs_dataset.csv derivado del archivo original tech_jobs_dataset.xlsx.**.
#
# Se exporto a CSV para evitar dependencias adicionales y mantener el notebook completamente ejecutable.

# %%
ruta_dataset = r'tech_jobs_dataset.csv'
df = pd.read_csv(ruta_dataset)
df
# Out:
#               Job_Title   Level  Location  Technology    Framework  \
# 0     Backend Developer  Junior  Medellín      Python      FastAPI
# 1    Frontend Developer  Junior  Medellín  JavaScript        React
# 2  Full Stack Developer  Junior  Medellín  JavaScript      Node.js
# 3     Backend Developer  Junior  Medellín        Java  Spring Boot
# 4          Data Analyst  Junior  Medellín      Python       Pandas
# 5    Software Developer  Junior  Medellín          C#         .NET
# 6     Backend Developer  Junior  Medellín      Python       Django
# 7    Frontend Developer  Junior  Medellín  JavaScript       Vue.js
# 8  Full Stack Developer  Junior  Medellín  JavaScript      Angular
# 9          Data Analyst  Junior  Medellín           R        Shiny
#
#      Database  Experience_Years
# 0  PostgreSQL                 1
# 1         NaN                 1
# 2     MongoDB                 1
# 3       MySQL                 1
# 4  SQL Server                 1
# ...

# %% [markdown]
# ## 3. Inspeccion rapida
#
# Se visualizan registros iniciales, finales y dimensiones generales del dataset.

# %%
df.head()
# Out:
#               Job_Title   Level  Location  Technology    Framework  \
# 0     Backend Developer  Junior  Medellín      Python      FastAPI
# 1    Frontend Developer  Junior  Medellín  JavaScript        React
# 2  Full Stack Developer  Junior  Medellín  JavaScript      Node.js
# 3     Backend Developer  Junior  Medellín        Java  Spring Boot
# 4          Data Analyst  Junior  Medellín      Python       Pandas
#
#      Database  Experience_Years
# 0  PostgreSQL                 1
# 1         NaN                 1
# 2     MongoDB                 1
# 3       MySQL                 1
# 4  SQL Server                 1

# %%
df.tail()
# Out:
#               Job_Title   Level  Location  Technology Framework    Database  \
# 5    Software Developer  Junior  Medellín          C#      .NET  SQL Server
# 6     Backend Developer  Junior  Medellín      Python    Django  PostgreSQL
# 7    Frontend Developer  Junior  Medellín  JavaScript    Vue.js         NaN
# 8  Full Stack Developer  Junior  Medellín  JavaScript   Angular     MongoDB
# 9          Data Analyst  Junior  Medellín           R     Shiny  PostgreSQL
#
#    Experience_Years
# 5                 1
# 6                 1
# 7                 1
# 8                 1
# 9                 1

# %%
df.shape
# Out:
# (10, 7)

# %% [markdown]
# ## 4. Diagnostico principal
#
# La salida de `info()` resume no nulos, tipos de datos y memoria consumida.

# %%
buffer = io.StringIO()
df.info(buf=buffer)
print(buffer.getvalue())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Job_Title         10 non-null     str
#  1   Level             10 non-null     str
#  2   Location          10 non-null     str
#  3   Technology        10 non-null     str
#  4   Framework         10 non-null     str
#  5   Database          8 non-null      str
#  6   Experience_Years  10 non-null     int64
# dtypes: int64(1), str(6)
# memory usage: 692.0 bytes

# %% [markdown]
# ## 5. Resumen estadistico
#
# Se revisan por separado las variables numericas y las variables categoricas.

# %%
df.describe()
# Out:
#        Experience_Years
# count             10.00
# mean               1.00
# std                0.00
# min                1.00
# 25%                1.00
# 50%                1.00
# 75%                1.00
# max                1.00

# %%
df.describe(include=['object', 'string'])

# %% [markdown]
# ## 6. Interpretacion inicial
#
# - El dataset es pequeno pero suficiente para aplicar un flujo formal de diagnostico.
# - Los valores faltantes en Database provienen de marcadores como N/A y deben interpretarse con criterio de negocio.
# - La columna Experience_Years presenta baja variabilidad, aspecto importante para futuras etapas analiticas.
